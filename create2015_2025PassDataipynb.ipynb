# %% [markdown]
# <a href="https://colab.research.google.com/github/gschnitkey/PCM/blob/main/create2015_2025PassDataipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np


from google.colab import data_table
data_table.enable_dataframe_formatter()
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.name "gschnitkey"
# !git config --global user.email "gschnitkey@gmail.com"

# %%
# !git clone https://github.com/gschnitkey/PCM.git
# Out:
# Cloning into 'PCM'...
# ...

# %%
'''
The following file came from Laura. I got this on May 10, 2026. It includes data for the
past years: 2015 to 2025.
'''

passData = pd.read_excel('/content/drive/MyDrive/data/pcm-2025/2025 Pass Data.xlsx')

passdata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_26395/4154210976.py in <cell line: 0>()
#       6 passData = pd.read_excel('/content/drive/MyDrive/data/pcm-2025/2025 Pass Data.xlsx')
#       7
# ----> 8 passdata
#
# NameError: name 'passdata' is not defined
